# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
crash_df=sns.load_dataset("car_crashes")

# %% [markdown]
# >A)Heatmaps

# %%
crash_df.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
plt.figure(figsize=(9,4))
sns.set_context("paper", font_scale=1.8)

crash_mx = crash_df.select_dtypes(include='number').corr()

sns.heatmap(crash_mx, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
flights = sns.load_dataset('flights')

flights_pivot = flights.pivot_table(
    index="month",
    columns="year",
    values="passengers"
)

sns.heatmap(flights_pivot, cmap="Blues", linecolor="white", linewidths=1)
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_3056\3360953047.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights_pivot = flights.pivot_table(
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# >B)Cluster Map

# %%
iris= sns.load_dataset("iris")
species= iris.pop("species")
sns.clustermap(iris)

# %%
sns.clustermap(flights_pivot, cmap="viridis", standard_scale=1)
