# %%
import matplotlib as mpt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Linestyle

# %%
#   You can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:

y_pt= np.array([3,1,8,4])

plt.plot(y_pt, linestyle=":")

# %%
#   Use a dashed line 

ypt=np.array([4,8,7,6])

plt.plot(ypt, ls="dashed")

# %% [markdown]
# Shorter Syntax
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %%
plt.plot(y_pt, ls="-.")

# %% [markdown]
# Line Styles

# %%
line_styles=pd.DataFrame({"Style" :
                           ["Solid(Default)", "Dotted", "Dashed","Dashdot","None"] ,
                             "     Or" :
                              ["-",":","--","-.","or" ]})

print(line_styles.to_string(index=False))
# Out:
#          Style      Or
# Solid(Default)       -
#         Dotted       :
#         Dashed      --
#        Dashdot      -.
#           None      or

# %% [markdown]
# Line Color

# %%
#   You can use the keyword argument color or the shorter c to set the color of the line.

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'y')
plt.show()

# %%
#   You can also use Hexadecimal color values(https://www.w3schools.com/colors/colors_hexadecimal.asp)


plt.plot(ypoints, color = '#1797cd')
plt.show()

# %%
#   Or any of the 140 supported color names.(https://www.w3schools.com/colors/colors_names.asp)

plt.plot(ypoints, c = 'Indigo')
plt.show()

# %% [markdown]
# Line Width
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points:

# %%
plt.plot(ypoints, linewidth=12.2)
plt.show()

# %% [markdown]
# Multiple Lines
#
# You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
y1=np.array([7,5,4,9])
x1 = np.array([0, 1, 2, 3])
y2=np.array([1,8,3,6])
x2 = np.array([0, 1, 2, 3])

plt.plot(x1,y1, x2, y2)
