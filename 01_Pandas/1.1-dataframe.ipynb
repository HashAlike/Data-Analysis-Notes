# %%
import pandas as pd

# %% [markdown]
# DataFrame
#
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
pd.DataFrame({'Yes': [50, 21], 'No' : [79,12]})
# Out:
#    Yes  No
# 0   50  79
# 1   21  12

# %%
pd.DataFrame({'Alessandro' : ["I like it","I don't like it"],'Selena' : ["J'aime bien","Je n'aime pas ça"]})
# Out:
#         Alessandro            Selena
# 0        I like it       J'aime bien
# 1  I don't like it  Je n'aime pas ça

# %%
pd.DataFrame(
    {
        'English' : ["I like it","I don't like it"],
        'French' : ["J'aime bien","Je n'aime pas ça"]
        },
        index= ["Beğenme", "Beğenmeme"])
# Out:
#                    English            French
# Beğenme          I like it       J'aime bien
# Beğenmeme  I don't like it  Je n'aime pas ça

# %%
songs= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\spotify_tracks.csv", index_col=0)

# %%
songs.shape
# Out:
# (6300, 7)

# %%
songs.head()
# Out:
#                                                                  name  \
# id
# 7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
#
#                            genre                        artists  \
# id
# 7kr3xZk4yb3YSZ4VFtg2Qt  acoustic                  Billy Raffoul
# 1kJygfS4eoVziBBI93MSYp  acoustic                  Billy Raffoul
# 6lynns69p4zTCRxmmiSY1x  acoustic  Molly Hocking, Bailey Rushlow
# 1RC9slv335IfLce5vt9KTW  acoustic              The Goo Goo Dolls
# 5o9L8xBuILoVjLECSBi7Vo  acoustic  Guus Dielissen, Casper Esmann
#
#                                                                 album  \
# id
# 7kr3xZk4yb3YSZ4VFtg2Qt                                           1975
# ...
