# %%
import pandas as pd

# %%
pokemon= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\Pokemon.csv")

# %%
songs= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\spotify_tracks.csv", index_col=1)

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.rename(columns={"#" : "No.:"})
# Out:
#      No.:                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur    Grass  Poison    318  45      49       49
# 1       2                Ivysaur    Grass  Poison    405  60      62       63
# 2       3               Venusaur    Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4       4             Charmander     Fire     NaN    309  39      52       43
# ..    ...                    ...      ...     ...    ...  ..     ...      ...
# 795   719                Diancie     Rock   Fairy    600  50     100      150
# 796   719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797   720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798   720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799   721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
songs.head()
# Out:
#                                                                    id  \
# name
# Acoustic                                       7kr3xZk4yb3YSZ4VFtg2Qt
# Acoustic                                       1kJygfS4eoVziBBI93MSYp
# Here Comes the Sun - Acoustic                  6lynns69p4zTCRxmmiSY1x
# Acoustic #3                                    1RC9slv335IfLce5vt9KTW
# My Love Mine All Mine - Acoustic Instrumental  5o9L8xBuILoVjLECSBi7Vo
#
#                                                   genre  \
# name
# Acoustic                                       acoustic
# Acoustic                                       acoustic
# Here Comes the Sun - Acoustic                  acoustic
# Acoustic #3                                    acoustic
# My Love Mine All Mine - Acoustic Instrumental  acoustic
#
#                                                                      artists  \
# name
# Acoustic                                                       Billy Raffoul
# ...

# %%
songs.rename(columns={"id": "id number"})
# Out:
#                                                             id number  \
# name
# Acoustic                                       7kr3xZk4yb3YSZ4VFtg2Qt
# Acoustic                                       1kJygfS4eoVziBBI93MSYp
# Here Comes the Sun - Acoustic                  6lynns69p4zTCRxmmiSY1x
# Acoustic #3                                    1RC9slv335IfLce5vt9KTW
# My Love Mine All Mine - Acoustic Instrumental  5o9L8xBuILoVjLECSBi7Vo
# ...                                                               ...
# Voyage to Atlantis                             4uveHSzaz8YEbTF9j6QlCI
# L'Oiseau                                       4u15cjyziW2Ewn5Ek3082l
# The Daintree                                   56pHPaTeX2O9aVmTFYS8hV
# The Sorcerers Symphony                         6Ldyc5TsR4kaUsuHKcB2AD
# Fiore d'inverno                                3ry0f8ybk8upUBIk8unvmF
#
#                                                      genre  \
# name
# ...

# %%
pokemon.rename(index={0: "firstEntry", 1: "secondEntry"})
# Out:
#                #                   Name   Type 1  Type 2  Total  HP  Attack  \
# firstEntry     1              Bulbasaur    Grass  Poison    318  45      49
# secondEntry    2                Ivysaur    Grass  Poison    405  60      62
# 2              3               Venusaur    Grass  Poison    525  80      82
# 3              3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4              4             Charmander     Fire     NaN    309  39      52
# ...          ...                    ...      ...     ...    ...  ..     ...
# 795          719                Diancie     Rock   Fairy    600  50     100
# 796          719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797          720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798          720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799          721              Volcanion     Fire   Water    600  80     110
#
# ...

# %%
pokemon.set_index
songs.set_index
# Out:
# <bound method DataFrame.set_index of                                                                    id  \
# name
# Acoustic                                       7kr3xZk4yb3YSZ4VFtg2Qt
# Acoustic                                       1kJygfS4eoVziBBI93MSYp
# Here Comes the Sun - Acoustic                  6lynns69p4zTCRxmmiSY1x
# Acoustic #3                                    1RC9slv335IfLce5vt9KTW
# My Love Mine All Mine - Acoustic Instrumental  5o9L8xBuILoVjLECSBi7Vo
# ...                                                               ...
# Voyage to Atlantis                             4uveHSzaz8YEbTF9j6QlCI
# L'Oiseau                                       4u15cjyziW2Ewn5Ek3082l
# The Daintree                                   56pHPaTeX2O9aVmTFYS8hV
# The Sorcerers Symphony                         6Ldyc5TsR4kaUsuHKcB2AD
# Fiore d'inverno                                3ry0f8ybk8upUBIk8unvmF
#
#                                                      genre  \
# name
# ...

# %%
pokemon.rename_axis("Pokemon's", axis='rows').rename_axis("Speciallities", axis='columns')
# Out:
# Speciallities    #                   Name   Type 1  Type 2  Total  HP  Attack  \
# Pokemon's
# 0                1              Bulbasaur    Grass  Poison    318  45      49
# 1                2                Ivysaur    Grass  Poison    405  60      62
# 2                3               Venusaur    Grass  Poison    525  80      82
# 3                3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4                4             Charmander     Fire     NaN    309  39      52
# ...            ...                    ...      ...     ...    ...  ..     ...
# 795            719                Diancie     Rock   Fairy    600  50     100
# 796            719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797            720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798            720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799            721              Volcanion     Fire   Water    600  80     110
#
# ...

# %%
De_yt= pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\archive (1)\DEvideos.csv")
Fr_yt=pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Deneme\archive (1)\FRvideos.csv")

# %%
De_yt.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
Fr_yt.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
pd.concat([Fr_yt,De_yt])
# Out:
#           video_id trending_date  \
# 0      Ro6eob0LrCY      17.14.11
# 1      Yo84eqYwP98      17.14.11
# 2      ceqntSXE-10      17.14.11
# 3      WuTFI5qftCE      17.14.11
# 4      ee6OFs8TdEg      17.14.11
# ...            ...           ...
# 40835  fn5WNxy-Wcw      18.14.06
# 40836  zAFv43lxqHE      18.14.06
# 40837  zSXG5I6Y2fA      18.14.06
# 40838  5d115sePmaU      18.14.06
# 40839  go-F6xvezAM      18.14.06
#
#                                                    title  \
# 0               Malika LePen : Femme de Gauche - Trailer
# 1      LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
# 2      DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...
# 3                        PAPY GRENIER - METAL GEAR SOLID
# 4      QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...
# ...                                                  ...
# 40835  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
# 40836                                     YMS: The Visit
# ...

# %%
Fr_yt.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
De_yt.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
left= Fr_yt.set_index(["title","trending_date"] )
right=De_yt.set_index(["title","trending_date"])

# %%
left.join(right, lsuffix='_DE', rsuffix='_FR')
# Out:
#                                                                   video_id_DE  \
# title                                              trending_date
# Malika LePen : Femme de Gauche - Trailer           17.14.11       Ro6eob0LrCY
# LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce, ... 17.14.11       Yo84eqYwP98
# DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil ... 17.14.11       ceqntSXE-10
# PAPY GRENIER - METAL GEAR SOLID                    17.14.11       WuTFI5qftCE
# QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER T... 17.14.11       ee6OFs8TdEg
# ...                                                                       ...
# عاجل و رسمي : الملف الأمريكي يفوز بشرف تنظيم كأ... 18.14.06       coVXf3Q9xBk
# شاهد ملخص البرلمان اليوم بحضور اخنوش الدي يعطي ... 18.14.06       _umkjOQJvtw
# UN ANIME EXPLOSIF A VOIR ABSOLUMENT !              18.14.06       nt25ec7nzIM
# Նռան հատիկ, Սերիա 192 / Pomegranate seed / Nran... 18.14.06       NlxE_QQMRzg
# ...
