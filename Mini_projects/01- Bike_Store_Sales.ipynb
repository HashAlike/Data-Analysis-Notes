# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(r"C:\Users\musta\OneDrive\Belgeler\Yazılım\data-analysis-notes\Mini_projects\Mini_Data\sales_data.csv",
    parse_dates=['Date'], index_col=0)

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
sales.shape
# Out:
# (113036, 17)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
# ...

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
sales["Unit_Cost"].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %%
sales["Unit_Cost"].mean()
# Out:
# np.float64(267.296365759581)

# %%
sales["Unit_Cost"].max()
# Out:
# np.int64(2171)

# %%
sales["Unit_Cost"].median()
# Out:
# np.float64(9.0)

# %%
sales["Unit_Cost"].plot(kind= "box" , vert= False , figsize= (14,7))
# Out:
# <Axes: >

# %%
sales["Unit_Cost"].plot(kind= "density" , figsize= (14,7))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# What's the mean of Customers_Age?

# %%
its= sales["Customer_Age"].mean()
print(f"Ortalama müşteri yaşı = {its}'tir")
# Out:
# Ortalama müşteri yaşı = 35.91921157861212'tir

# %% [markdown]
# Go ahead and show a density (KDE) and a box plot with the Customer_Age data:

# %%
sales["Customer_Age"].plot(kind="density", figsize= (17,8), marker="*", ms=15 , mec="b" , mfc="c" )
# Out:
# <Axes: ylabel='Density'>

# %%
sales["Customer_Age"].plot(kind="box",vert= False,  figsize= (10,6))
# Out:
# <Axes: >

# %% [markdown]
# What's the mean of Order_Quantity?

# %%
sts= sales["Order_Quantity"].mean()
print(f"Ortalama sipariş adedi= {sts}'tür")
# Out:
# Ortalama sipariş adedi= 11.901659648253654'tür

# %%
sales["Order_Quantity"].shape
# Out:
# (113036,)

# %% [markdown]
# Go ahead and show a histogram and a box plot with the Order_Quantity data:

# %%
sales["Order_Quantity"].plot(kind="hist", figsize=(14,7),color="c" , bins="fd")
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales["Order_Quantity"].plot(kind="box", figsize=(14,5), vert=False)
# Out:
# <Axes: >

# %% [markdown]
# How many sales per year do we have?

# %%
vc= sales["Year"].value_counts()
vc
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
vc.plot(kind="pie", figsize=(14,6), shadow=True)
plt.legend(title="Year")

# %% [markdown]
# How many sales per month do we have?
# Go ahead and show a bar plot with the previous data:

# %%
mts= sales["Month"].value_counts()
mts
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
mts.plot(kind="bar" , figsize=(14,6), color="c", width=0.5 )
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Which country has the most sales quantity of sales?
# Go ahead and show a bar plot of the sales per country.

# %%
cst= sales["Country"].value_counts() 
cst.head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
cst.plot(kind="bar" , figsize=(12,5), color="m" , width=0.8)
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# Create a list of every product sold

# %%
sales["Product"].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales["Product"].value_counts().head(10).plot(kind="bar", figsize=(11,4), color="y" , width=0.75)
# Out:
# <Axes: xlabel='Product'>

# %%
sales["Product"].value_counts(normalize= True).head(10).plot(kind="bar", figsize=(11,4), color="r" , width=0.75)
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# Can you see any relationship between Unit_Cost and Unit_Price?

# %%
sales.plot(kind="scatter", x="Unit_Cost", y="Unit_Price", figsize=(14,6), color="r")
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# Can you see any relationship between Order_Quantity and Profit?

# %%
sales.plot(kind="scatter", y="Order_Quantity", x="Profit", figsize=(6,6), color="b")
# Out:
# <Axes: xlabel='Profit', ylabel='Order_Quantity'>

# %% [markdown]
# Can you see any relationship between Profit per Country?

# %%
sales[["Profit", "Country"]].boxplot(by="Country", figsize=(10,6), color="r")
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# Can you see any relationship between the Customer_Age per Country?

# %%
sales[["Customer_Age", "Country"]].boxplot(by="Country" , figsize=(10,6), color="y")
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# Add and calculate a new Calculated_Date column

# %%
sales["Calculated_Date"]=sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
sales["Calculated_Date"].head()
# Out:
# C:\Users\musta\AppData\Local\Temp\ipykernel_7024\899440679.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales["Calculated_Date"]=sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)
# Date
# 2013-11-26    2013-November-26
# 2015-11-26    2015-November-26
# 2014-03-23       2014-March-23
# 2016-03-23       2016-March-23
# 2014-05-15         2014-May-15
# Name: Calculated_Date, dtype: object

# %%
#sales["Calculated_Date"] = pd.to_datetime(
#    sales["Day"].astype(str) + " " +
#    sales["Month"] + " " +
#    sales["Year"].astype(str),
#    format="%d %B %Y"
#)
#sales["Calculated_Date"].head()

# %%
sales["Calculated_Date"]= pd.to_datetime(sales["Calculated_Date"])
sales["Calculated_Date"].head()
# Out:
# Date
# 2013-11-26   2013-11-26
# 2015-11-26   2015-11-26
# 2014-03-23   2014-03-23
# 2016-03-23   2016-03-23
# 2014-05-15   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# How did sales evolve through the years?

# %%
sales["Calculated_Date"].value_counts().plot(kind="line", figsize= (17,8))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %% [markdown]
# Increase 50 U$S revenue to every sale

# %%
sales["Revenue"].head()
# Out:
# Date
# 2013-11-26    1050
# 2015-11-26    1050
# 2014-03-23    2501
# 2016-03-23    2188
# 2014-05-15     518
# Name: Revenue, dtype: int64

# %%
sales["Revenue"] += 50 
sales["Revenue"].head()
# Out:
# Date
# 2013-11-26    1100
# 2015-11-26    1100
# 2014-03-23    2551
# 2016-03-23    2238
# 2014-05-15     568
# Name: Revenue, dtype: int64

# %% [markdown]
# How many orders were made in Canada or France?

# %%
sales.loc[(sales["Country"]== "Canada") | (sales["Country"]== "France")].shape[0]
# Out:
# 25176

# %% [markdown]
# How many Bike Racks orders were made from Canada?

# %%
sales.loc[(sales["Country"]== "Canada") & (sales["Sub_Category"]== "Bike Racks")].shape[0]
# Out:
# 104

# %% [markdown]
# How many orders were made in each region (state) of France?

# %%
sales.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
france_states.plot(kind="bar", figsize= (14,6), color="m")
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# How many sales were made per category?

# %%
sales["Product_Category"].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
sales["Product_Category"].value_counts().plot(kind="pie", figsize=(14,7))

plt.legend(loc=1, title="Category")

# %% [markdown]
# How many orders were made per accessory sub-categories?

# %%
accessories= sales.loc[sales["Product_Category"]=="Accessories", "Sub_Category"].value_counts()

accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories.plot(kind="bar", figsize=(12,5), color="b")
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# How many orders were made per bike sub-categories?

# %%
bikes= sales.loc[sales["Product_Category"]== "Bikes", "Sub_Category"].value_counts()

bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
bikes.plot(kind="pie", figsize=(8,8))
plt.legend(loc=1, title="Bicycle categories")

# %% [markdown]
# Which gender has the most amount of sales?

# %%
sales["Customer_Gender"].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales["Customer_Gender"].value_counts().plot(kind="bar" ,
                                              figsize=(10,3),
                                                color=["Blue", "Purple"])
# Out:
# <Axes: xlabel='Customer_Gender'>
